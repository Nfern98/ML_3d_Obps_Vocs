# %% [markdown]
# # Install libraries

# %%
# !git clone https://github.com/openmm/pdbfixer.git
# !pip install openmm
# %cd pdbfixer/
# !python setup.py install
# !pip install PyBioMed
# !pip install mordred
# !pip install openpyxl
# !pip install scikit-learn
# !pip install xgboost
# !pip install lightgbm
# !pip install hyperopt
# !pip install bayesian-optimization
# !pip install scikit-optimize
# %cd /home/nfernandez/unit
# Out:
# fatal: la ruta de destino 'pdbfixer' ya existe y no es un directorio vacío.
# ERROR: Could not find a version that satisfies the requirement openmm (from versions: none)
# ERROR: No matching distribution found for openmm
# /home/nfernandez/pdbfixer
# /home/nfernandez/.local/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# running install
# /home/nfernandez/unit/entorno/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# /home/nfernandez/unit/entorno/lib/python3.7/site-packages/setuptools/command/easy_install.py:147: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   EasyInstallDeprecationWarning,
# ...

# %%
# Miniconda
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /home/nfernandez/unit/entorno

import sys
sys.path.append('/home/nfernandez/unit/entorno/bin/conda create -n myenv python=3.7 -y')

# 4. RDKit
# !pip install rdkit-pypi
from rdkit import*
# 5. Smina
# !wget https://downloads.sourceforge.net/project/smina/smina.static
# !chmod u+x smina.static
# !./smina.static --help
# Out:
# --2024-12-27 17:55:22--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolviendo repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Conectando con repo.anaconda.com (repo.anaconda.com)[104.16.32.241]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 416 Requested Range Not Satisfiable
#
#     El fichero ya ha sido totalmente recuperado, no hay nada que hacer.
#
# PREFIX=/home/nfernandez/unit/entorno
# Unpacking payload ...
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# installation finished.
# ...
# --2024-12-27 17:55:33--  https://downloads.sourceforge.net/project/smina/smina.static
# Resolviendo downloads.sourceforge.net (downloads.sourceforge.net)... 104.18.12.149, 104.18.13.149, 2606:4700::6812:d95, ...
# Conectando con downloads.sourceforge.net (downloads.sourceforge.net)[104.18.12.149]:443... conectado.
# ...

# %%
# %cd /home/nfernandez/unit
# !wget https://ccsb.scripps.edu/download/532/ -O mgltools.tar.gz
# !tar -xvzf mgltools.tar.gz
# %cd /home/nfernandez/unit/mgltools_x86_64Linux2_1.5.7
# Out:
# /home/nfernandez/unit
# --2024-12-27 17:55:35--  https://ccsb.scripps.edu/download/532/
# Resolviendo ccsb.scripps.edu (ccsb.scripps.edu)... 192.26.252.19
# Conectando con ccsb.scripps.edu (ccsb.scripps.edu)[192.26.252.19]:443...
# /home/nfernandez/.local/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 112380857 (107M) [application/x-gzip]
# Grabando a: «mgltools.tar.gz»
#
# mgltools.tar.gz     100%[===================>] 107,17M  5,11MB/s    en 31s
#
# 2024-12-27 17:56:09 (3,42 MB/s) - «mgltools.tar.gz» guardado [112380857/112380857]
#
# mgltools_x86_64Linux2_1.5.7/
# mgltools_x86_64Linux2_1.5.7/README
# mgltools_x86_64Linux2_1.5.7/MGLToolsPckgs.tar.gz
# mgltools_x86_64Linux2_1.5.7/Tools/
# mgltools_x86_64Linux2_1.5.7/Tools/mglenv.csh
# ...

# %%
# !./install.sh
# %cd /home/nfernandez/unit
# Out:
# Installing MGLTools to /home/nfernandez/unit/mgltools_x86_64Linux2_1.5.7
# Installing Python Interpreter to
# bin/
# bin/cython
# bin/sample
# bin/pip
# bin/python2.7
# bin/pilfile.py
# bin/pildriver.py
# bin/idle
# bin/python
# bin/cythonize
# bin/ipcontroller
# bin/iptest2
# bin/ipcluster2
# bin/pip2.7
# bin/easy_install
# bin/ipengine2
# bin/2to3
# bin/pilprint.py
# bin/radical-utils-mongodb.py
# bin/ipcluster
# bin/pilconvert.py
# bin/pilfont.py
# bin/python2.7-config
# bin/sagapython-version
# bin/python2
# bin/pydoc
# bin/prody
# bin/radical-utils-pylint.sh
# bin/pip2
# bin/ipengine
# bin/iptest
# bin/smtpd.py
# bin/radical-utils-version
# bin/f2py
# bin/ipcontroller2
# bin/python-config
# bin/radical-utils-fix-headers.pl
# bin/python2-config
# bin/ipython2
# bin/pygmentize
# bin/evol
# bin/runAdt
# bin/ipython
# bin/easy_install-2.7
# bin/cygdb
# include/
# include/tclDecls.h
# include/python2.7/
# include/python2.7/bufferobject.h
# include/python2.7/opcode.h
# ...

# %%
# !pip install propy3 BioPython
